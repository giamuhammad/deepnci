# %%
import os
import numpy as np
import pandas as pd
import psi4
from scipy.ndimage import zoom
from pathlib import Path

# %%
# ============================================================
# KONFIGURASI
# ============================================================

INPUT_DIR = "./raw_data"
CUBE_OUT_DIR = "./density"
NPY_OUT_DIR = "./density_npy"
PROP_OUT = "./chemical_properties.csv"

METHOD = "M06-2X"
PROP_METHOD = "B3LYP"
BASIS = "6-31G*"
TARGET_GRID = (137, 133, 124)

os.makedirs(CUBE_OUT_DIR, exist_ok=True)
os.makedirs(NPY_OUT_DIR, exist_ok=True)

psi4.core.set_num_threads(16)
psi4.set_memory("8GB")

psi4.set_options({
    "reference": "RKS",
    "cubeprop_tasks": ["density"],            # Only generate Dt.cube
    "dft_radial_points": 99,
    "dft_spherical_points": 590,
    "cubeprop_filepath": CUBE_OUT_DIR
})

# ============================================================
#  HELPER
# ============================================================

def load_cube_density(filename):
    """Parse cube file → kembalikan array density 3D."""
    with open(filename) as f:
        lines = f.readlines()

    idx = 2
    natoms = int(lines[idx].split()[0])
    idx += 1

    nx = int(lines[idx].split()[0]); idx += 1
    ny = int(lines[idx].split()[0]); idx += 1
    nz = int(lines[idx].split()[0]); idx += 1

    idx += natoms

    raw = " ".join(lines[idx:]).split()
    data = np.array(raw, dtype=float)

    return data.reshape((nx, ny, nz))


def resample_grid(vol, target):
    zoom_factors = (target[0]/vol.shape[0],
                    target[1]/vol.shape[1],
                    target[2]/vol.shape[2])
    return zoom(vol, zoom_factors, order=1).astype(np.float32)
# Out:
#   Threads set to 16 by Python driver.
#
#   Memory set to   7.451 GiB by Python driver.

# %%
# ============================================================
#  MAIN LOOP MOLEKUL
# ============================================================

all_props = []

xyz_files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".xyz")])
print(f"Jumlah molekul: {len(xyz_files)}")
print("Mulai memproses...\n")

for fname in xyz_files:
    base = fname.replace(".xyz", "")
    fpath = os.path.join(INPUT_DIR, fname)

    print(f">>> Processing {fname}")


    with open(fpath, "r") as f:
        xyz_body = f.read()

    with open(fpath) as f:
        lines = f.read().strip().splitlines()
    

    mol = psi4.geometry(xyz_body)


    # -------------------------------
    # 2. DFT Energy + Wavefunction
    # -------------------------------
    E, wfn = psi4.energy(f"{METHOD}/{BASIS}", molecule=mol, return_wfn=True)

    # -------------------------------
    # 3. Frequency → Thermochemistry
    # -------------------------------
    psi4.frequency(f"{METHOD}/{BASIS}", molecule=mol)

    # -------------------------------
    # 4. cubeprop → menghasilkan Dt.cube
    # -------------------------------
    psi4.cubeprop(wfn)

    # PSI4 OUTPUT (selalu):
    # Da.cube, Db.cube, Ds.cube, Dt.cube, geom.xyz
    dt_file = "Dt.cube"

    dtf_path = os.path.join(CUBE_OUT_DIR, dt_file)
    if not os.path.exists(dtf_path):
        print(f"   ERROR: Dt.cube tidak ditemukan. SKIP.")
        continue

    # rename Dt.cube → nama_input.density.cube
    new_cube = os.path.join(CUBE_OUT_DIR, f"{base}.density.cube")
    os.rename(dtf_path, new_cube)

    # bersihkan file cube lain
    for extra in ["Da.cube", "Db.cube", "Ds.cube", "geom.xyz"]:
        if os.path.exists(extra):
            os.remove(extra)

    # -------------------------------
    # 5. Load density & resize grid
    # -------------------------------
    vol = load_cube_density(new_cube)
    vol_res = resample_grid(vol, TARGET_GRID)

    np.save(os.path.join(NPY_OUT_DIR, f"{base}.npy"), vol_res)


print("\n==== SELESAI ====")
print(f"Cube density disimpan di: {CUBE_OUT_DIR}")
print(f"NPY grid disimpan di:     {NPY_OUT_DIR}")
# Out:
# Jumlah molekul: 3
# Mulai memproses...
#
# >>> Processing 1155_ammoniadimer09.xyz
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on gm-mpc
# *** at Sat Nov 15 15:31:18 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-31G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5     entry N          line   128 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#     atoms 2-4, 6-8 entry H          line    44 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                        16 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2h
#     Full point group: C2h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -0.430785003000     1.394320911500     0.000000000000    14.003074004430
#          H           -0.394955729500     2.001359060500    -0.809565000000     1.007825032230
#          H           -0.394955729500     2.001359060500     0.809565000000     1.007825032230
#          H            0.430785003000     0.859300360500     0.000000000000     1.007825032230
#          N            0.430785003000    -1.394320911500     0.000000000000    14.003074004430
#          H            0.394955729500    -2.001359060500    -0.809565000000     1.007825032230
#          H           -0.430785003000    -0.859300360500     0.000000000000     1.007825032230
#          H            0.394955729500    -2.001359060500     0.809565000000     1.007825032230
#
#   Running in c2h symmetry.
#
#   Rotational constants: A =      4.65190  B =      0.21534  C =      0.21087 [cm^-1]
#   Rotational constants: A = 139460.56726  B =   6455.77469  C =   6321.69230 [MHz]
#   Nuclear repulsion =   41.684436200818631
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G*
#     Blend: 6-31G*
#     Number of shells: 24
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional  (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            590
#     Total Points           =         445596
#     Total Blocks           =           3182
#     Max Points             =            256
#     Max Functions          =             42
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 5     entry N          line   171 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-4, 6-8 entry H          line    51 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.005 GiB; user supplied 4.473 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:              16
#     Memory [MiB]:              4580
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.1134
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G* AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 102
#     Number of basis functions: 312
#     Number of Cartesian functions: 312
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 1.115 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.6905549343E-02.
#   Reciprocal condition number of the overlap matrix is 3.4384756871E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        15      15
#      Bg         6       6
#      Au         6       6
#      Bu        15      15
#    -------------------------
#     Total      42      42
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -112.57588904650405   -1.12576e+02   0.00000e+00
#    @DF-RKS iter   1:  -112.37287464859365    2.03014e-01   4.58194e-02 DIIS/ADIIS
#    @DF-RKS iter   2:  -112.56490742644964   -1.92033e-01   4.77291e-02 DIIS/ADIIS
#    @DF-RKS iter   3:  -113.02912216280347   -4.64215e-01   4.83293e-03 DIIS/ADIIS
#    @DF-RKS iter   4:  -113.03410392940457   -4.98177e-03   7.95033e-04 DIIS/ADIIS
#    @DF-RKS iter   5:  -113.03428606262551   -1.82133e-04   1.23716e-04 DIIS/ADIIS
#    @DF-RKS iter   6:  -113.03429578224362   -9.71962e-06   2.69413e-05 DIIS
#    @DF-RKS iter   7:  -113.03429643389228   -6.51649e-07   5.15509e-06 DIIS
#    @DF-RKS iter   8:  -113.03429644902543   -1.51332e-08   4.88612e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   19.9999996606 ; deviation = -3.394e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Bu   -14.718826     1Ag   -14.718820     2Ag    -0.947219
#        2Bu    -0.934820     3Ag    -0.539130     1Au    -0.519344
#        1Bg    -0.515375     3Bu    -0.490785     4Bu    -0.323747
#        4Ag    -0.316574
#
#     Virtual:
#
#        5Ag     0.130163     5Bu     0.165776     2Au     0.221794
#        2Bg     0.229643     6Bu     0.241277     6Ag     0.278875
#        3Au     0.678768     7Ag     0.742680     7Bu     0.752804
#        3Bg     0.795974     8Ag     0.802375     8Bu     0.942274
#        4Au     0.991957     9Bu     1.002238     9Ag     1.002460
#       10Ag     1.014547     4Bg     1.025736    10Bu     1.055032
#       11Bu     1.166857    11Ag     1.318434     5Bg     1.738118
#        5Au     1.738751    12Ag     1.742170    12Bu     1.800725
#       13Ag     2.012881    13Bu     2.025932     6Au     2.466336
#        6Bg     2.486915    14Bu     2.492334    14Ag     2.508360
#       15Bu     3.715242    15Ag     3.777715
#
#     Final Occupation by Irrep:
#              Ag    Bg    Au    Bu
#     DOCC [     4,    1,    1,    4 ]
#     NA   [     4,    1,    1,    4 ]
#     NB   [     4,    1,    1,    4 ]
#
#   @DF-RKS Final Energy:  -113.03429644902543
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             41.6844362008186309
#     One-Electron Energy =                -235.0155999902627570
#     Two-Electron Energy =                  88.0207454687781592
#     DFT Exchange-Correlation Energy =      -7.7238781283594609
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -113.0342964490254332
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on gm-mpc at Sat Nov 15 15:31:22 2025
# Module time:
# 	user time   =      51.36 seconds =       0.86 minutes
# 	system time =       2.23 seconds =       0.04 minutes
# 	total time  =          4 seconds =       0.07 minutes
# Total time:
# 	user time   =   10343.80 seconds =     172.40 minutes
# 	system time =     310.07 seconds =       5.17 minutes
# 	total time  =       6116 seconds =     101.93 minutes
#
#          ----------------------------------------------------------
#                                    FINDIF
#                      R. A. King and Jonathon Misiewicz
#          ----------------------------------------------------------
#
#   Using finite-differences of gradients to determine vibrational frequencies and
#   normal modes. Resulting frequencies are only valid at stationary points.
#     Generating geometries for use with 3-point formula.
#     Displacement size will be 5.00e-03.
#     Number of atoms is 8.
#     Number of irreps is 4.
#     Number of SALCs is 21.
#     Translations projected? 1. Rotations projected? 0.
#     Index of SALCs per irrep:
#       1 :  0  1  2  3  4  5  6
#       2 :  7  8  9  10  11
#       3 :  12  13  14  15
#       4 :  16  17  18  19  20
#     Number of SALCs per irrep:
#       Irrep 1: 7
#       Irrep 2: 5
#       Irrep 3: 4
#       Irrep 4: 5
#     Number of geometries (including reference) is 29.
#     Number of displacements per irrep:
#       Irrep 1: 14
#       Irrep 2: 5
#       Irrep 3: 4
#       Irrep 4: 5
#  29 displacements needed ...
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //    FiniteDifference Computations  //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Saturday, 15 November 2025 01:49PM
#
#     Process ID: 1757
#     Host:       gm-mpc
#     PSIDATADIR: /home/gia/anaconda3/envs/psi4/share/psi4
#     Memory:     7.5 GiB
#     Threads:    16
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'gradient',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'CUBEPROP_FILEPATH': './density',
#               'CUBEPROP_TASKS': ['DENSITY'],
#               'DFT_RADIAL_POINTS': 99,
#               'DFT_SPHERICAL_POINTS': 590,
#               'PARENT_SYMMETRY': 'C2h(Z)',
#               'REFERENCE': 'RKS',
#               'SCF_TYPE': 'DF',
#               'SCF__D_CONVERGENCE': 1e-06,
#               'SCF__E_CONVERGENCE': 1e-06,
#               'SCF__INTS_TOLERANCE': 1e-12,
#               'function_kwargs': {}},
#  'model': {'basis': '6-31g*', 'method': 'm06-2x'},
#  'molecule': {'atom_labels': ['', '', '', '', '', '', '', ''],
#               'atomic_numbers': [7, 1, 1, 1, 7, 1, 1, 1],
#               'extras': {},
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0],
#               'fragment_multiplicities': [1],
#               'fragments': [[0, 1, 2, 3, 4, 5, 6, 7]],
#               'geometry': [-0.814065674624529, 2.6348846537337227, 0.0, -0.7463581604354054, 3.7820205030485843,
#                            -1.5298561307562666, -0.7463581604354054, 3.7820205030485843, 1.5298561307562666,
#                            0.8140656746245287, 1.62384234085218, 0.0, 0.814065674624529, -2.6348846537337227, 0.0,
#                            0.7463581604354054, -3.7820205030485843, -1.5298561307562666, -0.8140656746245287,
#                            -1.62384234085218, 0.0, 0.7463581604354054, -3.7820205030485843, 1.5298561307562666],
#               'mass_numbers': [14, 1, 1, 1, 14, 1, 1, 1],
#               'masses': [14.00307400443, 1.00782503223, 1.00782503223, 1.00782503223, 14.00307400443, 1.00782503223,
#                          1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H6N2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': '0.29.0'},
#               'real': [True, True, True, True, True, True, True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['N', 'H', 'H', 'H', 'N', 'H', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': '0.29.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on gm-mpc
# *** at Sat Nov 15 15:31:22 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-31G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5     entry N          line   128 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#     atoms 2-4, 6-8 entry H          line    44 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                        16 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2h
#     Full point group: C2h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -0.814065674625     2.634884653734     0.000000000000    14.003074004430
#          H           -0.746358160435     3.782020503049    -1.529856130756     1.007825032230
#          H           -0.746358160435     3.782020503049     1.529856130756     1.007825032230
#          H            0.814065674625     1.623842340852     0.000000000000     1.007825032230
#          N            0.814065674625    -2.634884653734     0.000000000000    14.003074004430
#          H            0.746358160435    -3.782020503049    -1.529856130756     1.007825032230
#          H           -0.814065674625    -1.623842340852     0.000000000000     1.007825032230
#          H            0.746358160435    -3.782020503049     1.529856130756     1.007825032230
#
#   Running in c2h symmetry.
#
#   Rotational constants: A =      4.65190  B =      0.21534  C =      0.21087 [cm^-1]
#   Rotational constants: A = 139460.56726  B =   6455.77469  C =   6321.69230 [MHz]
#   Nuclear repulsion =   41.684436200818631
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G*
#     Blend: 6-31G*
#     Number of shells: 24
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional  (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            590
#     Total Points           =         445596
#     Total Blocks           =           3182
#     Max Points             =            256
#     Max Functions          =             42
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 5     entry N          line   171 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-4, 6-8 entry H          line    51 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.005 GiB; user supplied 4.473 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:              16
#     Memory [MiB]:              4580
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.1134
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G* AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 102
#     Number of basis functions: 312
#     Number of Cartesian functions: 312
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 1.115 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.6905549343E-02.
#   Reciprocal condition number of the overlap matrix is 3.4384756871E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        15      15
#      Bg         6       6
#      Au         6       6
#      Bu        15      15
#    -------------------------
#     Total      42      42
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -112.57588904648260   -1.12576e+02   0.00000e+00
#    @DF-RKS iter   1:  -112.37287464856752    2.03014e-01   4.58194e-02 DIIS/ADIIS
#    @DF-RKS iter   2:  -112.56490742642370   -1.92033e-01   4.77291e-02 DIIS/ADIIS
#    @DF-RKS iter   3:  -113.02912216278646   -4.64215e-01   4.83293e-03 DIIS/ADIIS
#    @DF-RKS iter   4:  -113.03410392938765   -4.98177e-03   7.95033e-04 DIIS/ADIIS
#    @DF-RKS iter   5:  -113.03428606260866   -1.82133e-04   1.23716e-04 DIIS/ADIIS
#    @DF-RKS iter   6:  -113.03429578222664   -9.71962e-06   2.69413e-05 DIIS
#    @DF-RKS iter   7:  -113.03429643387520   -6.51649e-07   5.15509e-06 DIIS
#    @DF-RKS iter   8:  -113.03429644900852   -1.51333e-08   4.88612e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   19.9999996606 ; deviation = -3.394e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Bu   -14.718826     1Ag   -14.718820     2Ag    -0.947219
#        2Bu    -0.934820     3Ag    -0.539130     1Au    -0.519344
#        1Bg    -0.515375     3Bu    -0.490785     4Bu    -0.323747
#        4Ag    -0.316574
#
#     Virtual:
#
#        5Ag     0.130163     5Bu     0.165776     2Au     0.221794
#        2Bg     0.229643     6Bu     0.241277     6Ag     0.278875
#        3Au     0.678768     7Ag     0.742680     7Bu     0.752804
#        3Bg     0.795974     8Ag     0.802375     8Bu     0.942274
#        4Au     0.991957     9Bu     1.002238     9Ag     1.002460
#       10Ag     1.014547     4Bg     1.025736    10Bu     1.055032
#       11Bu     1.166857    11Ag     1.318434     5Bg     1.738118
#        5Au     1.738751    12Ag     1.742170    12Bu     1.800725
#       13Ag     2.012881    13Bu     2.025932     6Au     2.466336
#        6Bg     2.486915    14Bu     2.492334    14Ag     2.508360
#       15Bu     3.715242    15Ag     3.777715
#
#     Final Occupation by Irrep:
#              Ag    Bg    Au    Bu
#     DOCC [     4,    1,    1,    4 ]
#     NA   [     4,    1,    1,    4 ]
#     NB   [     4,    1,    1,    4 ]
#
#   @DF-RKS Final Energy:  -113.03429644900852
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             41.6844362008186309
#     One-Electron Energy =                -235.0155999902520136
#     Two-Electron Energy =                  88.0207454687836872
#     DFT Exchange-Correlation Energy =      -7.7238781283588143
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -113.0342964490085222
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on gm-mpc at Sat Nov 15 15:31:26 2025
# Module time:
# 	user time   =      57.87 seconds =       0.96 minutes
# 	system time =       2.85 seconds =       0.05 minutes
# 	total time  =          4 seconds =       0.07 minutes
# Total time:
# 	user time   =   10404.44 seconds =     173.41 minutes
# 	system time =     313.17 seconds =       5.22 minutes
# 	total time  =       6120 seconds =     102.00 minutes
#
# *** tstart() called on gm-mpc
# *** at Sat Nov 15 15:31:26 2025
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2h
#     Full point group: C2h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -0.814065674625     2.634884653734     0.000000000000    14.003074004430
#          H           -0.746358160435     3.782020503049    -1.529856130756     1.007825032230
#          H           -0.746358160435     3.782020503049     1.529856130756     1.007825032230
#          H            0.814065674625     1.623842340852     0.000000000000     1.007825032230
#          N            0.814065674625    -2.634884653734     0.000000000000    14.003074004430
#          H            0.746358160435    -3.782020503049    -1.529856130756     1.007825032230
#          H           -0.814065674625    -1.623842340852     0.000000000000     1.007825032230
#          H            0.746358160435    -3.782020503049     1.529856130756     1.007825032230
#
#   Nuclear repulsion =   41.684436200818631
#
#   ==> Basis Set <==
#
#   Basis Set: 6-31G*
#     Blend: 6-31G*
#     Number of shells: 24
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:             16
#     Integrals threads:          16
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G* AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 102
#     Number of basis functions: 312
#     Number of Cartesian functions: 312
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional  (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            590
#     Total Points           =         445596
#     Total Blocks           =           3182
#     Max Points             =            256
#     Max Functions          =             42
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.003681912564     0.000179882680     0.000000000000
#        2        0.000346868419    -0.002691436557     0.003415967466
#        3        0.000346868419    -0.002691436557    -0.003415967466
#        4       -0.004296143360     0.001795204359     0.000000000000
#        5       -0.003681912564    -0.000179882680     0.000000000000
#        6       -0.000346868419     0.002691436557     0.003415967466
#        7        0.004296143360    -0.001795204359     0.000000000000
#        8       -0.000346868419     0.002691436557    -0.003415967466
#
#
# *** tstop() called on gm-mpc at Sat Nov 15 15:31:27 2025
# Module time:
# 	user time   =      10.53 seconds =       0.18 minutes
# 	system time =       0.32 seconds =       0.01 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =   10415.01 seconds =     173.58 minutes
# 	system time =     313.49 seconds =       5.22 minutes
# 	total time  =       6121 seconds =     102.02 minutes
#
#     Psi4 stopped on: Saturday, 15 November 2025 03:31PM
#     Psi4 wall time for execution: 0:00:04.84
#
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Saturday, 15 November 2025 01:49PM
#
#     Process ID: 1757
#     Host:       gm-mpc
#     PSIDATADIR: /home/gia/anaconda3/envs/psi4/share/psi4
#     Memory:     7.5 GiB
#     Threads:    16
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'gradient',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'CUBEPROP_FILEPATH': './density',
#               'CUBEPROP_TASKS': ['DENSITY'],
#               'DFT_RADIAL_POINTS': 99,
#               'DFT_SPHERICAL_POINTS': 590,
#               'PARENT_SYMMETRY': 'C2h(Z)',
#               'REFERENCE': 'RKS',
#               'SCF_TYPE': 'DF',
#               'SCF__D_CONVERGENCE': 1e-06,
#               'SCF__E_CONVERGENCE': 1e-06,
#               'SCF__INTS_TOLERANCE': 1e-12,
#               'function_kwargs': {'write_orbitals': False}},
#  'model': {'basis': '6-31g*', 'method': 'm06-2x'},
#  'molecule': {'atom_labels': ['', '', '', '', '', '', '', ''],
#               'atomic_numbers': [7, 1, 1, 1, 7, 1, 1, 1],
#               'extras': {},
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0],
#               'fragment_multiplicities': [1],
#               'fragments': [[0, 1, 2, 3, 4, 5, 6, 7]],
#               'geometry': [-0.8150104820862337, 2.6348846537337227, 0.0, -0.7463581604354055, 3.7820205030485843,
#                            -1.5298561307562666, -0.7463581604354055, 3.7820205030485843, 1.5298561307562666,
#                            0.8140656746245287, 1.62384234085218, 0.0, 0.8150104820862337, -2.6348846537337227, 0.0,
#                            0.7463581604354055, -3.7820205030485843, -1.5298561307562666, -0.8140656746245287,
#                            -1.62384234085218, 0.0, 0.7463581604354055, -3.7820205030485843, 1.5298561307562666],
#               'mass_numbers': [14, 1, 1, 1, 14, 1, 1, 1],
#               'masses': [14.00307400443, 1.00782503223, 1.00782503223, 1.00782503223, 14.00307400443, 1.00782503223,
#                          1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H6N2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': '0.29.0'},
#               'real': [True, True, True, True, True, True, True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['N', 'H', 'H', 'H', 'N', 'H', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': '0.29.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on gm-mpc
# *** at Sat Nov 15 15:31:27 2025
#
#    => Loading Basis Set <=
#
#     Name: 6-31G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5     entry N          line   128 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#     atoms 2-4, 6-8 entry H          line    44 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/6-31gs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                        16 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2h
#     Full point group: C2h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N           -0.815010482086     2.634884653734     0.000000000000    14.003074004430
#          H           -0.746358160435     3.782020503049    -1.529856130756     1.007825032230
#          H           -0.746358160435     3.782020503049     1.529856130756     1.007825032230
#          H            0.814065674625     1.623842340852     0.000000000000     1.007825032230
#          N            0.815010482086    -2.634884653734     0.000000000000    14.003074004430
#          H            0.746358160435    -3.782020503049    -1.529856130756     1.007825032230
#          H           -0.814065674625    -1.623842340852     0.000000000000     1.007825032230
#          H            0.746358160435    -3.782020503049     1.529856130756     1.007825032230
#
#   Running in c2h symmetry.
#
#   Rotational constants: A =      4.65013  B =      0.21531  C =      0.21084 [cm^-1]
#   Rotational constants: A = 139407.27768  B =   6454.77939  C =   6320.84742 [MHz]
#   Nuclear repulsion =   41.680088951904366
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G*
#     Blend: 6-31G*
#     Number of shells: 24
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional  (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            590
#     Total Points           =         445592
#     Total Blocks           =           3188
#     Max Points             =            256
#     Max Functions          =             42
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 5     entry N          line   171 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-4, 6-8 entry H          line    51 file /home/gia/anaconda3/envs/psi4/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.005 GiB; user supplied 4.473 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:              16
#     Memory [MiB]:              4580
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.1134
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G* AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 102
#     Number of basis functions: 312
#     Number of Cartesian functions: 312
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 1.115 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.6912990404E-02.
#   Reciprocal condition number of the overlap matrix is 3.4402167144E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        15      15
#      Bg         6       6
#      Au         6       6
#      Bu        15      15
#    -------------------------
#     Total      42      42
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -112.57516398440714   -1.12575e+02   0.00000e+00
#    @DF-RKS iter   1:  -112.37277363101590    2.02390e-01   4.58239e-02 DIIS/ADIIS
#    @DF-RKS iter   2:  -112.56476061848205   -1.91987e-01   4.77364e-02 DIIS/ADIIS
#    @DF-RKS iter   3:  -113.02912149536589   -4.64361e-01   4.83626e-03 DIIS/ADIIS
#    @DF-RKS iter   4:  -113.03411003357461   -4.98854e-03   7.96426e-04 DIIS/ADIIS
#    @DF-RKS iter   5:  -113.03429263743041   -1.82604e-04   1.23718e-04 DIIS/ADIIS
#    @DF-RKS iter   6:  -113.03430235659607   -9.71917e-06   2.69394e-05 DIIS
#    @DF-RKS iter   7:  -113.03430300803649   -6.51440e-07   5.16004e-06 DIIS
#    @DF-RKS iter   8:  -113.03430302320984   -1.51734e-08   4.88855e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   19.9999996525 ; deviation = -3.475e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Bu   -14.718891     1Ag   -14.718886     2Ag    -0.947197
#        2Bu    -0.934806     3Ag    -0.538998     1Au    -0.519351
#        1Bg    -0.515384     3Bu    -0.490605     4Bu    -0.323830
#        4Ag    -0.316623
#
#     Virtual:
#
#        5Ag     0.130118     5Bu     0.165749     2Au     0.221794
#        2Bg     0.229629     6Bu     0.241093     6Ag     0.278759
#        3Au     0.678796     7Ag     0.742654     7Bu     0.752776
#        3Bg     0.795942     8Ag     0.802380     8Bu     0.942239
#        4Au     0.991939     9Ag     1.002287     9Bu     1.002325
#       10Ag     1.014553     4Bg     1.025686    10Bu     1.054615
#       11Bu     1.167108    11Ag     1.318535     5Bg     1.738097
#        5Au     1.738730    12Ag     1.742206    12Bu     1.800709
#       13Ag     2.012410    13Bu     2.025478     6Au     2.466334
#        6Bg     2.486936    14Bu     2.491975    14Ag     2.507972
#       15Bu     3.715119    15Ag     3.777529
#
#     Final Occupation by Irrep:
#              Ag    Bg    Au    Bu
#     DOCC [     4,    1,    1,    4 ]
#     NA   [     4,    1,    1,    4 ]
#     NB   [     4,    1,    1,    4 ]
#
#   @DF-RKS Final Energy:  -113.03430302320984
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             41.6800889519043665
#     One-Electron Energy =                -235.0071944842724463
#     Two-Electron Energy =                  88.0165210141996823
#     DFT Exchange-Correlation Energy =      -7.7237185050414396
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -113.0343030232098442
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on gm-mpc at Sat Nov 15 15:31:31 2025
# Module time:
# 	user time   =      58.84 seconds =       0.98 minutes
# 	system time =       2.97 seconds =       0.05 minutes
# 	total time  =          4 seconds =       0.07 minutes
# Total time:
# 	user time   =   10475.58 seconds =     174.59 minutes
# 	system time =     316.64 seconds =       5.28 minutes
# 	total time  =       6125 seconds =     102.08 minutes
#
# *** tstart() called on gm-mpc
# *** at Sat Nov 15 15:31:31 2025
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2h
#     Full point group: C2h
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
# ...
#   post-proj  all modes:['242.7946i' '204.8826i' '189.9506i' '125.3094i' '69.9939i' '0.0000i'
#  '0.0000i' '0.0000i' '0.0000i' '0.0000' '0.0001' '225.0281' '1117.3445'
#  '1122.4610' '1711.4509' '1720.6903' '1722.2005' '1728.5202' '3533.5789'
#  '3535.2098' '3667.3709' '3668.2506' '3677.5571' '3677.7781']
#
#   Vibration                       1                   2                   3
#   Freq [cm^-1]                242.7946i           204.8826i           189.9506i
#   Irrep                           Bu                  Au                  Bg
#   Reduced mass [u]              1.0449              1.0172              1.0865
#   Force const [mDyne/A]        -0.0363             -0.0252             -0.0231
#   Turning point v=0 [a0]        0.0000              0.0000              0.0000
#   RMS dev v=0 [a0 u^1/2]        0.0000              0.0000              0.0000
#   IR activ [km/mol]            260.4809            43.3276              0.0000
#   Char temp [K]                 0.0000              0.0000              0.0000
#   ----------------------------------------------------------------------------------
#       1   N                0.02 -0.03  0.00    0.00 -0.00 -0.02    0.00 -0.00 -0.06
#       2   H               -0.31 -0.01 -0.00   -0.00  0.38  0.27   -0.01  0.38  0.23
#       3   H               -0.31 -0.01  0.00    0.00 -0.38  0.27    0.01 -0.38  0.23
#       4   H                0.32  0.45  0.00    0.00  0.00 -0.27   -0.00 -0.00 -0.30
#       5   N                0.02 -0.03 -0.00    0.00 -0.00 -0.02   -0.00  0.00  0.06
#       6   H               -0.31 -0.01  0.00    0.00 -0.38  0.27   -0.01  0.38 -0.23
#       7   H                0.32  0.45  0.00    0.00  0.00 -0.27    0.00  0.00  0.30
#       8   H               -0.31 -0.01 -0.00   -0.00  0.38  0.27    0.01 -0.38 -0.23
#
#   Vibration                       4                   5                   12
#   Freq [cm^-1]                125.3094i            69.9939i            225.0281
#   Irrep                           Au                  Ag                  Ag
#   Reduced mass [u]              1.0347              3.5989              1.1547
#   Force const [mDyne/A]        -0.0096             -0.0104              0.0345
#   Turning point v=0 [a0]        0.0000              0.0000              0.6807
#   RMS dev v=0 [a0 u^1/2]        0.0000              0.0000              0.5172
#   IR activ [km/mol]            127.3076             0.0000              0.0000
#   Char temp [K]                 0.0000              0.0000             323.7653
#   ----------------------------------------------------------------------------------
#       1   N                0.00 -0.00 -0.03   -0.06  0.31 -0.00    0.06 -0.04 -0.00
#       2   H                0.42  0.08  0.05   -0.12  0.32  0.00   -0.31 -0.03 -0.00
#       3   H               -0.42 -0.08  0.05   -0.12  0.32 -0.00   -0.31 -0.03  0.00
#       4   H                0.00 -0.00  0.35    0.01  0.41 -0.00    0.35  0.43  0.00
#       5   N               -0.00 -0.00 -0.03    0.06 -0.31  0.00   -0.06  0.04 -0.00
#       6   H               -0.42 -0.08  0.05    0.12 -0.32  0.00    0.31  0.03 -0.00
#       7   H                0.00  0.00  0.35   -0.01 -0.41  0.00   -0.35 -0.43  0.00
#       8   H                0.42  0.08  0.05    0.12 -0.32 -0.00    0.31  0.03  0.00
#
#   Vibration                       13                  14                  15
#   Freq [cm^-1]                1117.3445           1122.4610           1711.4509
#   Irrep                           Bu                  Ag                  Bu
#   Reduced mass [u]              1.1796              1.1765              1.0651
#   Force const [mDyne/A]         0.8677              0.8733              1.8382
#   Turning point v=0 [a0]        0.3022              0.3019              0.2570
#   RMS dev v=0 [a0 u^1/2]        0.2321              0.2316              0.1875
#   IR activ [km/mol]            391.8944             0.0000             27.7714
#   Char temp [K]               1607.6100           1614.9714           2462.3968
#   ----------------------------------------------------------------------------------
#       1   N               -0.07 -0.05  0.00   -0.06 -0.05  0.00    0.03 -0.04  0.00
#       2   H                0.35  0.16  0.13    0.33  0.16  0.13   -0.15  0.36  0.28
#       3   H                0.35  0.16 -0.13    0.33  0.16 -0.13   -0.15  0.36 -0.28
#       4   H                0.22  0.35 -0.00    0.23  0.36 -0.00   -0.08 -0.18 -0.00
#       5   N               -0.07 -0.05 -0.00    0.06  0.05  0.00    0.03 -0.04 -0.00
#       6   H                0.35  0.16 -0.13   -0.33 -0.16  0.13   -0.15  0.36 -0.28
#       7   H                0.22  0.35  0.00   -0.23 -0.36 -0.00   -0.08 -0.18  0.00
#       8   H                0.35  0.16  0.13   -0.33 -0.16 -0.13   -0.15  0.36  0.28
#
#   Vibration                       16                  17                  18
#   Freq [cm^-1]                1720.6903           1722.2005           1728.5202
#   Irrep                           Bg                  Ag                  Au
#   Reduced mass [u]              1.0634              1.0616              1.0662
#   Force const [mDyne/A]         1.8551              1.8551              1.8770
#   Turning point v=0 [a0]        0.2565              0.2566              0.2556
#   RMS dev v=0 [a0 u^1/2]        0.1870              0.1870              0.1866
#   IR activ [km/mol]             0.0000              0.0000             39.0306
#   Char temp [K]               2475.6903           2477.8631           2486.9557
#   ----------------------------------------------------------------------------------
#       1   N                0.00 -0.00 -0.05    0.03 -0.04  0.00   -0.00  0.00 -0.05
#       2   H               -0.29  0.13  0.05   -0.15  0.36  0.28   -0.28  0.13  0.06
#       3   H                0.29 -0.13  0.05   -0.15  0.36 -0.28    0.28 -0.13  0.06
#       4   H               -0.00 -0.00  0.54   -0.09 -0.20 -0.00    0.00  0.00  0.54
#       5   N               -0.00  0.00  0.05   -0.03  0.04 -0.00    0.00 -0.00 -0.05
#       6   H               -0.29  0.13 -0.05    0.15 -0.36  0.28    0.28 -0.13  0.06
#       7   H                0.00  0.00 -0.54    0.09  0.20  0.00   -0.00 -0.00  0.54
#       8   H                0.29 -0.13 -0.05    0.15 -0.36 -0.28   -0.28  0.13  0.06
#
#   Vibration                       19                  20                  21
#   Freq [cm^-1]                3533.5789           3535.2098           3667.3709
#   Irrep                           Ag                  Bu                  Ag
#   Reduced mass [u]              1.0278              1.0277              1.0901
#   Force const [mDyne/A]         7.5612              7.5677              8.6379
#   Turning point v=0 [a0]       Warning: thermodynamics relations excluded imaginary frequencies: ['242.7946i' '204.8826i' '189.9506i' '125.3094i' '69.9939i']
# Warning: used thermodynamics relations inappropriate for low-frequency modes: ['225.0281']
#  0.1821              0.1820              0.1735
#   RMS dev v=0 [a0 u^1/2]        0.1305              0.1305              0.1281
#   IR activ [km/mol]             0.0000              3.9885              0.0000
#   Char temp [K]               5084.0333           5086.3798           5276.5302
#   ----------------------------------------------------------------------------------
#       1   N               -0.02 -0.01  0.00   -0.02 -0.01 -0.00   -0.03  0.05  0.00
#       2   H               -0.01  0.22 -0.32   -0.01  0.22 -0.32   -0.01 -0.18  0.26
#       3   H               -0.01  0.22  0.32   -0.01  0.22  0.32   -0.01 -0.18 -0.26
#       4   H                0.36 -0.26  0.00    0.36 -0.26 -0.00    0.46 -0.29  0.00
#       5   N                0.02  0.01  0.00   -0.02 -0.01 -0.00    0.03 -0.05  0.00
#       6   H                0.01 -0.22 -0.32   -0.01  0.22  0.32    0.01  0.18  0.26
#       7   H               -0.36  0.26  0.00    0.36 -0.26  0.00   -0.46  0.29  0.00
#       8   H                0.01 -0.22  0.32   -0.01  0.22 -0.32    0.01  0.18 -0.26
#
#   Vibration                       22                  23                  24
#   Freq [cm^-1]                3668.2506           3677.5571           3677.7781
#   Irrep                           Bu                  Bg                  Au
#   Reduced mass [u]              1.0899              1.0895              1.0893
#   Force const [mDyne/A]         8.6409              8.6817              8.6810
#   Turning point v=0 [a0]        0.1735              0.1733              0.1734
#   RMS dev v=0 [a0 u^1/2]        0.1281              0.1279              0.1279
#   IR activ [km/mol]             9.5100              0.0000              0.9748
#   Char temp [K]               5277.7959           5291.1859           5291.5039
#   ----------------------------------------------------------------------------------
#       1   N               -0.03  0.05 -0.00    0.00 -0.00 -0.06    0.00 -0.00 -0.06
#       2   H               -0.01 -0.18  0.26   -0.01 -0.30  0.40   -0.01 -0.30  0.40
#       3   H               -0.01 -0.18 -0.26    0.01  0.30  0.40    0.01  0.30  0.40
#       4   H                0.47 -0.29 -0.00   -0.00  0.00 -0.01   -0.00  0.00 -0.01
#       5   N               -0.03  0.05 -0.00    0.00 -0.00  0.06    0.00 -0.00 -0.06
#       6   H               -0.01 -0.18 -0.26   -0.01 -0.30 -0.40    0.01  0.30  0.40
#       7   H                0.47 -0.29 -0.00   -0.00  0.00  0.01   -0.00  0.00 -0.01
#       8   H               -0.01 -0.18  0.26    0.01  0.30 -0.40   -0.01 -0.30  0.40
#
#   ==> Thermochemistry Components <==
#
#   Entropy, S
#     Electronic S                             0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K] (multiplicity = 1)
#     Translational S                         36.507 [cal/(mol K)]      152.745 [J/(mol K)]       0.05817748 [mEh/K] (mol. weight = 34.0531 [u], P = 101325.00 [Pa])
#     Rotational S                            21.042 [cal/(mol K)]       88.038 [J/(mol K)]       0.03353194 [mEh/K] (symmetry no. = 2)
#     Vibrational S                            2.052 [cal/(mol K)]        8.584 [J/(mol K)]       0.00326934 [mEh/K]
#   Total S                                   59.600 [cal/(mol K)]      249.367 [J/(mol K)]       0.09497877 [mEh/K]
#   Correction S                               0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   Constant volume heat capacity, Cv
#     Electronic Cv                            0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#     Translational Cv                         2.981 [cal/(mol K)]       12.472 [J/(mol K)]       0.00475022 [mEh/K]
#     Rotational Cv                            2.981 [cal/(mol K)]       12.472 [J/(mol K)]       0.00475022 [mEh/K]
#     Vibrational Cv                           2.466 [cal/(mol K)]       10.316 [J/(mol K)]       0.00392918 [mEh/K]
#   Total Cv                                   8.427 [cal/(mol K)]       35.259 [J/(mol K)]       0.01342962 [mEh/K]
#   Correction Cv                              0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   Constant pressure heat capacity, Cp
#     Electronic Cp                            0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#     Translational Cp                         4.968 [cal/(mol K)]       20.786 [J/(mol K)]       0.00791703 [mEh/K]
#     Rotational Cp                            2.981 [cal/(mol K)]       12.472 [J/(mol K)]       0.00475022 [mEh/K]
#     Vibrational Cp                           2.466 [cal/(mol K)]       10.316 [J/(mol K)]       0.00392918 [mEh/K]
#   Total Cp                                  10.414 [cal/(mol K)]       43.574 [J/(mol K)]       0.01659643 [mEh/K]
#   Correction Cp                              0.000 [cal/(mol K)]        0.000 [J/(mol K)]       0.00000000 [mEh/K]
#
#   ==> Thermochemistry Energy Analysis <==
#
#   Raw electronic energy, E_e
#   Total E_e, Electronic energy at well bottom                                          -113.03118019 [Eh]
#
#   Zero-point vibrational energy, ZPVE = Sum_i omega_i / 2,  E_0 = E_e + ZPVE
#     Vibrational ZPVE                        44.470 [kcal/mol]      186.064 [kJ/mol]       0.07086796 [Eh]       15553.720 [cm^-1]
#   Correction ZPVE to E_e                    44.470 [kcal/mol]      186.064 [kJ/mol]       0.07086796 [Eh]       15553.720 [cm^-1]
#   Total E_0, Enthalpy at 0 [K]                                                         -112.96031223 [Eh]
#   *** Absolute enthalpy, not an enthalpy of formation ***
#
#   Thermal (internal) energy, E (includes ZPVE and finite-temperature corrections)
#     Electronic contrib to E beyond E_e       0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational contrib to E               0.889 [kcal/mol]        3.718 [kJ/mol]       0.00141628 [Eh]
#     Rotational contrib to E                  0.889 [kcal/mol]        3.718 [kJ/mol]       0.00141628 [Eh]
#     Vibrational contrib to E                44.832 [kcal/mol]      187.577 [kJ/mol]       0.07144438 [Eh]
#   Correction E                              46.609 [kcal/mol]      195.014 [kJ/mol]       0.07427694 [Eh]
#   Total E, Thermal (internal) energy at  298.15 [K]                                    -112.95690325 [Eh]
#
#   Enthalpy, H_trans = E_trans + k_B * T = E_trans + P * V
#     Electronic contrib to H beyond E_e       0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational contrib to H               1.481 [kcal/mol]        6.197 [kJ/mol]       0.00236046 [Eh]
#     Rotational contrib to H                  0.889 [kcal/mol]        3.718 [kJ/mol]       0.00141628 [Eh]
#     Vibrational contrib to H                44.832 [kcal/mol]      187.577 [kJ/mol]       0.07144438 [Eh]
#   Correction H                              47.202 [kcal/mol]      197.493 [kJ/mol]       0.07522112 [Eh]
#   Total H, Enthalpy at  298.15 [K]                                                     -112.95595907 [Eh]
#   *** Absolute enthalpy, not an enthalpy of formation ***
#
#   Gibbs free energy, G = H - T * S
#     Electronic contrib to G beyond E_e       0.000 [kcal/mol]        0.000 [kJ/mol]       0.00000000 [Eh]
#     Translational contrib to G              -9.403 [kcal/mol]      -39.344 [kJ/mol]      -0.01498515 [Eh]
#     Rotational contrib to G                 -5.385 [kcal/mol]      -22.530 [kJ/mol]      -0.00858127 [Eh]
#     Vibrational contrib to G                44.220 [kcal/mol]      185.018 [kJ/mol]       0.07046963 [Eh]
#   Correction G                              29.432 [kcal/mol]      123.144 [kJ/mol]       0.04690320 [Eh]
#   Total G, Gibbs energy at  298.15 [K]                                                 -112.98427699 [Eh]
#   *** Absolute Gibbs energy, not a free energy of formation ***
#
#   ==> One Electron Grid Properties (v2.0) <==
#
#   ==> CubicScalarGrid <==
#
#     Filepath     = ./density
#     Total Points =           245100
#     XYZ Blocking =               10
#     X Points     =               50
#     Y Points     =               86
#     Z Points     =               57
#     X Spacing    =        2.000E-01
#     Y Spacing    =        2.000E-01
#     Z Spacing    =        2.000E-01
#     X Minimum    =       -4.900E+00
#     Y Minimum    =       -8.500E+00
#     Z Minimum    =       -5.600E+00
#     X Maximum    =        4.900E+00
#     Y Maximum    =        8.500E+00
#     Z Maximum    =        5.600E+00
#
#   Basis Set: 6-31G*
#     Blend: 6-31G*
#     Number of shells: 24
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#
# ==== SELESAI ====
# Cube density disimpan di: ./density
# NPY grid disimpan di:     ./density_npy

# %%
main()
# Out:
# Found 3 .xyz files. Processing with Psi4 method M06-2X/6-31G* using 16 threads.
# [12:19:30] Processing '1155_ammoniadimer09' ...
# Unhandled error for sample_data/1155_ammoniadimer09.xyz: unsupported operand type(s) for |: 'list' and 'list'
# [12:19:30] Processing '1156_ammoniadimer10' ...
# Unhandled error for sample_data/1156_ammoniadimer10.xyz: unsupported operand type(s) for |: 'list' and 'list'
# [12:19:30] Processing '1157_ammoniadimer12' ...
# Unhandled error for sample_data/1157_ammoniadimer12.xyz: unsupported operand type(s) for |: 'list' and 'list'
# No properties collected.
# Per-sample densities saved in psi4_out/density_npy. Not combining into one file (SAVE_COMBINED_DENSITIES=False).
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1320/1287368036.py", line 366, in main
#     props, dens_path = process_single_xyz(xp, idx=i)
#   File "/tmp/ipykernel_1320/1287368036.py", line 130, in process_single_xyz
#     before = list_cube_files()
#   File "/tmp/ipykernel_1320/1287368036.py", line 16, in list_cube_files
#     return set(glob.glob(os.path.join(CUBE_TMP_DIR, "*.cube")) | glob.glob(os.path.join(".", "*.cube")))
# TypeError: unsupported operand type(s) for |: 'list' and 'list'
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1320/1287368036.py", line 366, in main
#     props, dens_path = process_single_xyz(xp, idx=i)
#   File "/tmp/ipykernel_1320/1287368036.py", line 130, in process_single_xyz
#     before = list_cube_files()
#   File "/tmp/ipykernel_1320/1287368036.py", line 16, in list_cube_files
#     return set(glob.glob(os.path.join(CUBE_TMP_DIR, "*.cube")) | glob.glob(os.path.join(".", "*.cube")))
# TypeError: unsupported operand type(s) for |: 'list' and 'list'
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1320/1287368036.py", line 366, in main
#     props, dens_path = process_single_xyz(xp, idx=i)
#   File "/tmp/ipykernel_1320/1287368036.py", line 130, in process_single_xyz
#     before = list_cube_files()
#   File "/tmp/ipykernel_1320/1287368036.py", line 16, in list_cube_files
#     return set(glob.glob(os.path.join(CUBE_TMP_DIR, "*.cube")) | glob.glob(os.path.join(".", "*.cube")))
# TypeError: unsupported operand type(s) for |: 'list' and 'list'
