# %%
import os
import numpy as np
import pandas as pd
import psi4
from scipy.ndimage import zoom
from pathlib import Path

# %%
# ============================================================
# KONFIGURASI
# ============================================================

INPUT_DIR = "./raw_data"
CUBE_OUT_DIR = "./density"
NPY_OUT_DIR = "./density_npy"

METHOD = "M06-2X"
PROP_METHOD = "B3LYP"
BASIS = "6-31G*"
TARGET_GRID = (137, 133, 124)

os.makedirs(CUBE_OUT_DIR, exist_ok=True)
os.makedirs(NPY_OUT_DIR, exist_ok=True)

psi4.core.set_num_threads(16)
psi4.set_memory("8GB")
#psi4.set_output_file(os.devnull, False)  # Redirect output ke null
psi4.core.be_quiet()  # Mode quiet untuk mengurangi output

psi4.set_options({
    "reference": "RKS",
    "cubeprop_tasks": ["density"],            # Only generate Dt.cube
    "dft_radial_points": 99,
    "dft_spherical_points": 590,
    "cubeprop_filepath": CUBE_OUT_DIR
})

# ============================================================
#  HELPER
# ============================================================

def load_cube_density(filename):
    """Parse cube file → kembalikan array density 3D."""
    with open(filename) as f:
        lines = f.readlines()

    idx = 2
    natoms = int(lines[idx].split()[0])
    idx += 1

    nx = int(lines[idx].split()[0]); idx += 1
    ny = int(lines[idx].split()[0]); idx += 1
    nz = int(lines[idx].split()[0]); idx += 1

    idx += natoms

    raw = " ".join(lines[idx:]).split()
    data = np.array(raw, dtype=float)

    return data.reshape((nx, ny, nz))


def resample_grid(vol, target):
    zoom_factors = (target[0]/vol.shape[0],
                    target[1]/vol.shape[1],
                    target[2]/vol.shape[2])
    return zoom(vol, zoom_factors, order=1).astype(np.float32)

# %%
# ============================================================
#  MAIN LOOP MOLEKUL
# ============================================================

all_props = []

xyz_files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".xyz")])
print(f"Jumlah molekul: {len(xyz_files)}")
print("Mulai memproses...\n")

for fname in xyz_files:
    base = fname.replace(".xyz", "")
    fpath = os.path.join(INPUT_DIR, fname)

    print(f">>> Processing {fname}")


    with open(fpath, "r") as f:
        xyz_body = f.read()

    with open(fpath) as f:
        lines = f.read().strip().splitlines()
    

    mol = psi4.geometry(xyz_body)


    # -------------------------------
    # 2. DFT Energy + Wavefunction
    # -------------------------------
    E, wfn = psi4.energy(f"{METHOD}/{BASIS}", molecule=mol, return_wfn=True)

    # -------------------------------
    # 3. Frequency → Thermochemistry
    # -------------------------------
    psi4.frequency(f"{METHOD}/{BASIS}", molecule=mol)

    # -------------------------------
    # 4. cubeprop → menghasilkan Dt.cube
    # -------------------------------
    psi4.cubeprop(wfn, quiet=True)

    # PSI4 OUTPUT (selalu):
    # Da.cube, Db.cube, Ds.cube, Dt.cube, geom.xyz
    dt_file = "Dt.cube"

    dtf_path = os.path.join(CUBE_OUT_DIR, dt_file)
    if not os.path.exists(dtf_path):
        print(f"   ERROR: Dt.cube tidak ditemukan. SKIP.")
        continue

    # rename Dt.cube → nama_input.density.cube
    new_cube = os.path.join(CUBE_OUT_DIR, f"{base}.density.cube")
    os.rename(dtf_path, new_cube)

    # bersihkan file cube lain
    for extra in ["Da.cube", "Db.cube", "Ds.cube", "geom.xyz"]:
        if os.path.exists(extra):
            os.remove(extra)

    # -------------------------------
    # 5. Load density & resize grid
    # -------------------------------
    vol = load_cube_density(new_cube)
    vol_res = resample_grid(vol, TARGET_GRID)

    np.save(os.path.join(NPY_OUT_DIR, f"{base}.npy"), vol_res)


print("\n==== SELESAI ====")
print(f"Cube density disimpan di: {CUBE_OUT_DIR}")
print(f"NPY grid disimpan di:     {NPY_OUT_DIR}")
# Out:
# Jumlah molekul: 1038
# Mulai memproses...
#
# >>> Processing 1155_ammoniadimer09.xyz
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 36
#      31 E, wfn = psi4.energy(f"{METHOD}/{BASIS}", molecule=mol, return_wfn=True, quiet=True)
#      33 # -------------------------------
#      34 # 3. Frequency → Thermochemistry
#      35 # -------------------------------
# ---> 36 psi4.frequency(f"{METHOD}/{BASIS}", molecule=mol, quiet=True)
#      38 # -------------------------------
#      39 # 4. cubeprop → menghasilkan Dt.cube
#      40 # -------------------------------
#      41 psi4.cubeprop(wfn, quiet=True)
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/psi4/driver/driver.py:1602, in frequency(name, **kwargs)
#    1599 molecule.update_geometry()
#    1601 # Compute the hessian
# -> 1602 H, wfn = hessian(name, return_wfn=True, molecule=molecule, **kwargs)
#    1604 # Project final frequencies?
#    1605 if wfn.gradient():  # available for analytic and any findif including totally symmetric space
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/psi4/driver/driver.py:1439, in hessian(name, **kwargs)
#    1435     return plan
#    1437 elif not isinstance(plan, AtomicComputer):
#    1438     # Advanced "Computer" active
# -> 1439     plan.compute()
#    1440     return plan.get_psi_results(return_wfn=return_wfn)
#    1442 else:
#    1443     # We have unpacked to an AtomicInput
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/psi4/driver/driver_findif.py:1311, in FiniteDifferenceComputer.compute(self, client)
#    1309 with p4util.hold_options_state():
#    1310     for t in self.task_list.values():
# -> 1311         t.compute(client=client)
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/psi4/driver/task_base.py:190, in AtomicComputer.compute(self, client)
#     184 gof = core.get_output_file()
#     186 # EITHER ...
#     187 # from psi4.driver import schema_wrapper
#     188 # self.result = schema_wrapper.run_qcschema(self.plan())
#     189 # ... OR ...
# --> 190 self.result = qcng.compute(
#     191     self.plan(),
#     192     "psi4",
#     193     raise_error=True,
#     194     # local_options below suitable for serial mode where each job takes all the resources of the parent Psi4 job.
#     195     #   distributed runs through QCFractal will likely need a different setup.
#     196     task_config={
#     197         # B -> GiB
#     198         "memory": core.get_memory() / (2 ** 30),
#     199         "ncores": core.get_num_threads(),
#     200     },
#     201 )
#     202 # ... END
#     203
#     204 #pp.pprint(self.result.dict())
#     205 #print(f"... JSON returns {self.result.success} >>>")
#     206 core.set_output_file(gof, True)
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/qcengine/compute.py:119, in compute(input_data, program, raise_error, task_config, local_options, return_dict)
#     116             except:
#     117                 raise
# --> 119 return handle_output_metadata(output_data, metadata, raise_error=raise_error, return_dict=return_dict)
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/qcengine/util.py:189, in handle_output_metadata(output_data, metadata, raise_error, return_dict)
#     186     raise ValueError(output_fusion["error"]["error_message"])
#     188 # Fill out provenance datadata
# --> 189 provenance_augments = get_provenance_augments()
#     190 provenance_augments["wall_time"] = metadata["wall_time"]
#     191 if "provenance" in output_fusion:
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/qcengine/config.py:350, in get_provenance_augments()
#     348 def get_provenance_augments() -> Dict[str, str]:
#     349     return {
# --> 350         "cpu": get_global("cpu_brand"),
#     351         "hostname": get_global("hostname"),
#     352         "username": get_global("username"),
#     353         "qcengine_version": get_information("version"),
#     354     }
#
# File ~/anaconda3/envs/psi4/lib/python3.10/site-packages/qcengine/config.py:69, in get_global(key)
#      67     return _global_values.copy()
#      68 else:
# ---> 69     return _global_values[key]
#
# KeyError: 'cpu_brand'
